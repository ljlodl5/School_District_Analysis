# %%
# Import Dependencies
import pandas as pd
import os

# %%
# Reference the file where the CSV is located
portland_crime_data_df = os.path.join("Resources", "crime_incident_data2017.csv")
# Import the data into a Pandas DataFrame
portland_crime_data_df = pd.read_csv(portland_crime_data_df)
portland_crime_data_df
# Out:
#                             Address  Case Number Crime Against  \
# 0                               NaN  17-X4762181        Person
# 1                               NaN  17-X4757824      Property
# 2          200 BLOCK OF SE 78TH AVE    17-900367      Property
# 3                               NaN  17-X4748982      Property
# 4                               NaN  17-X4748982      Property
# ...                             ...          ...           ...
# 41027   8800 BLOCK OF NE SANDY BLVD    17-285386       Society
# 41028     9700 BLOCK OF SE STARK ST    17-286082       Society
# 41029     9700 BLOCK OF SE STARK ST    17-286413       Society
# 41030               UNKNOWN ADDRESS    17-286445       Society
# 41031  8000 BLOCK OF SE POWELL BLVD    17-286659       Society
#
#           Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0                  NaN                  1     1/1/96           1/1/96
# ...

# %%
# look for missing values
portland_crime_data_df.count()
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %% [raw]
# # drop the null values
# portland_crime_data_df.dropna()

# %%
# verify counts

portland_crime_data_df.dropna().count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
portland_df = portland_crime_data_df["Offense Type"].unique()
portland_df
# Out:
# array(['Rape', 'Identity Theft',
#        'False Pretenses/Swindle/Confidence Game', 'All Other Larceny',
#        'Credit Card/ATM Fraud', 'Embezzlement', 'Shoplifting',
#        'Theft From Motor Vehicle', 'Motor Vehicle Theft', 'Burglary',
#        'Theft of Motor Vehicle Parts or Accessories',
#        'Counterfeiting/Forgery', 'Intimidation', 'Vandalism',
#        'Statutory Rape', 'Simple Assault', 'Theft From Building',
#        'Robbery', 'Fondling', 'Aggravated Assault',
#        'Theft From Coin-Operated Machine or Device',
#        'Sexual Assault With An Object', 'Hacking/Computer Invasion',
#        'Drug/Narcotic Violations', 'Pocket-Picking',
#        'Stolen Property Offenses', 'Weapons Law Violations',
#        'Purse-Snatching', 'Arson', 'Extortion/Blackmail', 'Sodomy',
#        'Prostitution', 'Kidnapping/Abduction',
#        'Drug Equipment Violations', 'Wire Fraud', 'Involuntary Servitude',
#        'Pornography/Obscene Material', 'Commercial Sex Acts',
# ...

# %%
# replace 
# Enable wide screen
pd.set_option('display.expand_frame_repr', False)

motortheft_df = portland_crime_data_df.replace('Theft From Motor Vehicle','Motor Vehicle Theft').replace('Theft of Motor Vehicle Parts or Accessories','Motor Vehicle Theft')
motortheft_df.head(30)
# Out:
#                           Address  Case Number Crime Against         Neighborhood  Number of Records Occur Date Occur Month Year  Occur Time  Offense Category  Offense Count                             Offense Type  Open Data Lat  Open Data Lon  Open Data X  Open Data Y Report Date Report Month Year
# 0                             NaN  17-X4762181        Person                  NaN                  1     1/1/96           1/1/96         800      Sex Offenses              1                                     Rape            NaN            NaN          NaN          NaN     1/26/17            1/1/17
# 1                             NaN  17-X4757824      Property           Centennial                  1    1/20/00           1/1/00        1615    Fraud Offenses              1                           Identity Theft            NaN            NaN          NaN          NaN     1/20/17            1/1/17
# ...

# %%
# Check to see if you comnbined similar offenses correctly in "Offense Type"

combinedmotor_df = motortheft_df["Offense Type"].unique()
combinedmotor_df
# Out:
# array(['Rape', 'Identity Theft',
#        'False Pretenses/Swindle/Confidence Game', 'All Other Larceny',
#        'Credit Card/ATM Fraud', 'Embezzlement', 'Shoplifting',
#        'Motor Vehicle Theft', 'Burglary', 'Counterfeiting/Forgery',
#        'Intimidation', 'Vandalism', 'Statutory Rape', 'Simple Assault',
#        'Theft From Building', 'Robbery', 'Fondling', 'Aggravated Assault',
#        'Theft From Coin-Operated Machine or Device',
#        'Sexual Assault With An Object', 'Hacking/Computer Invasion',
#        'Drug/Narcotic Violations', 'Pocket-Picking',
#        'Stolen Property Offenses', 'Weapons Law Violations',
#        'Purse-Snatching', 'Arson', 'Extortion/Blackmail', 'Sodomy',
#        'Prostitution', 'Kidnapping/Abduction',
#        'Drug Equipment Violations', 'Wire Fraud', 'Involuntary Servitude',
#        'Pornography/Obscene Material', 'Commercial Sex Acts',
#        'Assisting or Promoting Prostitution', 'Impersonation',
# ...
